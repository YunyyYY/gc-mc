# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
nr1w = [0.9021618,0.91765934,0.9379368,0.95108765]
nr1wt = [0.91341203,0.92298335,0.94107444,0.95593945]
nr5w = [0.9021618,0.91181445,0.91912806,0.9262069]
nr5wt = [0.9086468,0.9209418,0.92117655,0.9419526]
nr10w = [0.9021618,0.9098966,0.913428,0.92243236]
nr10wt = [0.9086468,0.9144648,0.9166853,0.9225823]

# %%
nc = [0, 50, 100, 150]
l1, = plt.plot(nc, nr1w, '-oc', label="Nr = 1 rating")
plt.plot(nc, nr1wt, '--oc')
l3, = plt.plot(nc, nr5w, '-v', color='orange', label="Nr = 5 rating")
plt.plot(nc, nr5wt, '--v', color='orange')
l5, = plt.plot(nc, nr10w, '-s', color='green', label="Nr = 10 rating")
plt.plot(nc, nr10wt, '--s', color='green')
# plt.legend()

import matplotlib.lines as mlines
feat1 = mlines.Line2D([], [], color='black', label='with feature')
feat2 = mlines.Line2D([], [], color='black', linestyle='--', label='without feature')
plt.legend(handles=[l1, l3, l5, feat1, feat2])
